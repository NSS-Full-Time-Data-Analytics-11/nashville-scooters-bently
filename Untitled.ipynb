# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import create_engine, text
import geopandas as gpd
from shapely.geometry import Point
import folium
import folium.plugins

# %%
db_name = 'scooters'
con_str = 'f"postgresql://postgres:postgres@localhost:5432/{db_name}'

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/scooters')

# %% [markdown]
# What is each company name represented in scooters table?

# %%
# Out:
#   companyname
# 0        Bird
# 1        Bolt
# 2      Gotcha
# 3        Jump
# 4        Lime
# 5        Lyft
# 6        Spin

# %% [markdown]
# What is each company name represented in trips table?

# %%
# Out:
#      companyname
# 0           Bird
# 1  Bolt Mobility
# 2         Gotcha
# 3           JUMP
# 4           Lime
# 5           Lyft
# 6           SPIN

# %% [markdown]
# What are minimum and maximum values for longitude and latitude?

# %%
# Out:
#    min_lat       max_lat   min_long  max_long
# 0      0.0  3.609874e+06 -97.443879       0.0

# %%
# Out:
#                pubdatetime   startdate      latitude
# 0  2019-07-16 13:57:19.230  2019-07-16  3.609874e+06
# 1  2019-07-16 14:02:19.390  2019-07-16  3.609874e+06
# 2  2019-07-16 13:07:17.510  2019-07-16  3.609874e+06
# 3  2019-07-16 13:12:17.600  2019-07-16  3.609874e+06
# 4  2019-07-16 13:17:18.007  2019-07-16  3.609874e+06
# 5  2019-07-16 13:22:18.187  2019-07-16  3.609874e+06
# 6  2019-07-16 13:27:18.393  2019-07-16  3.609874e+06
# 7  2019-07-16 13:32:18.437  2019-07-16  3.609874e+06
# 8  2019-07-16 13:37:18.660  2019-07-16  3.609874e+06
# 9  2019-07-16 13:42:18.747  2019-07-16  3.609874e+06
# 10 2019-07-16 13:47:18.947  2019-07-16  3.609874e+06
# 11 2019-07-16 13:52:18.997  2019-07-16  3.609874e+06
# 12 2019-07-16 13:57:19.230  2019-07-18  3.609874e+06
# 13 2019-07-16 14:02:19.390  2019-07-18  3.609874e+06
# 14 2019-07-16 13:07:17.510  2019-07-18  3.609874e+06
# 15 2019-07-16 13:12:17.600  2019-07-18  3.609874e+06
# 16 2019-07-16 13:17:18.007  2019-07-18  3.609874e+06
# 17 2019-07-16 13:22:18.187  2019-07-18  3.609874e+06
# 18 2019-07-16 13:27:18.393  2019-07-18  3.609874e+06
# 19 2019-07-16 13:32:18.437  2019-07-18  3.609874e+06
# 20 2019-07-16 13:37:18.660  2019-07-18  3.609874e+06
# 21 2019-07-16 13:42:18.747  2019-07-18  3.609874e+06
# 22 2019-07-16 13:47:18.947  2019-07-18  3.609874e+06
# 23 2019-07-16 13:52:18.997  2019-07-18  3.609874e+06
# 24 2019-07-16 13:57:19.230  2019-07-18  3.609874e+06

# %% [markdown]
# What are the minimum and maximum trip distance?

# %%
# Out:
#      min_trip      max_trap
# 0 -20324803.8  3.188448e+07

# %% [markdown]
# How many trips per company in trips table?

# %%
# Out:
#     total_trips    companyname
# 0   4134.142527           Bird
# 1   8094.324012  Bolt Mobility
# 2  11292.679898         Gotcha
# 3   5986.012366           JUMP
# 4   4198.204512           Lime
# 5   6474.656540           Lyft
# 6   2898.701852           SPIN

# %%
# Out:
#    total_trips companyname
# 0            1      Gotcha

# %%
# Out:
#    total_trips companyname
# 0           32        Bird

# %% [markdown]
# How many records by group of SUMD?

# %%
# Out:
#       total sumdgroup
# 0     26529   bicycle
# 1  59671463   scooter
# 2  13716051   Scooter

# %%
# Out:
#               pubdatetime   latitude  longitude                 sumdid  \
# 0 2019-05-01 00:04:56.910  36.150966 -86.852773  StandardNW5HJFO4R32LY
# 1 2019-05-01 00:09:56.970  36.150966 -86.852773  StandardNW5HJFO4R32LY
# 2 2019-05-01 00:14:58.037  36.150966 -86.852773  StandardNW5HJFO4R32LY
# 3 2019-05-01 00:19:57.383  36.150966 -86.852773  StandardNW5HJFO4R32LY
# 4 2019-05-01 00:24:57.743  36.150966 -86.852773  StandardNW5HJFO4R32LY
#
#    sumdtype  chargelevel sumdgroup  costpermin companyname
# 0  Standard        100.0   bicycle         0.0        Lime
# 1  Standard        100.0   bicycle         0.0        Lime
# 2  Standard        100.0   bicycle         0.0        Lime
# 3  Standard        100.0   bicycle         0.0        Lime
# 4  Standard        100.0   bicycle         0.0        Lime

# %%
# Out:
#                   sumdid  rides
# 0  Standard2UGJKREVB53HT     26
# 1  Standard5JXOV277MCWID      6
# 2  StandardNPOOZNUSGAXZN      9
# 3  StandardNUTLLXP4G37OI      6
# 4  StandardNW5HJFO4R32LY  26476
# 5  StandardZPUQESHVPP74J      6

# %%
# Out:
#                  sumdid  rides
# 0  PoweredBHQPF4NGORWCW      1
# 1  PoweredC7EZRZTYAREOS      1
# 2          PoweredIW4P9      2

# %%
# Out:
#    cost_per_min       trips companyname
# 0      0.117670   667671511        Bird
# 1      0.168505   250922613        Bolt
# 2      0.139500    66455346      Gotcha
# 3      0.059730    65830768        Jump
# 4      0.112198  2639292279        Lime
# 5      0.116997   918890343        Lyft
# 6      0.214905   305694135        Spin

# %%
loc_data = '''
SELECT DATE_TRUNC('day', pubtimestamp) AS timestamp,
       startlatitude,
       startlongitude,
       endlatitude,
       endlongitude,
       sumdid,
       companyname
FROM trips
'''
with engine.connect() as connection:
    locat_data = pd.read_sql(text(loc_data), con = connection)

# %%
locat_data
# Out:
#         timestamp  startlatitude  startlongitude  endlatitude  endlongitude  \
# 0      2019-07-18       36.16200       -86.77411     36.16195     -86.77408
# 1      2019-07-18       36.16950       -86.77270     36.16670     -86.77740
# 2      2019-07-18       36.17780       -86.77750     36.18080     -86.78720
# 3      2019-07-18       36.14970       -86.80170     36.14340     -86.80630
# 4      2019-07-18       36.17780       -86.77760     36.18030     -86.78820
# ...           ...            ...             ...          ...           ...
# 565517 2019-07-18       36.15697       -86.79420     36.15241     -86.79035
# 565518 2019-07-18       36.15215       -86.79755     36.14837     -86.81381
# 565519 2019-07-18       36.15661       -86.77522     36.15502     -86.78481
# 565520 2019-07-18       36.15315       -86.79598     36.14840     -86.81383
# 565521 2019-07-18       36.15865       -86.77731     36.15504     -86.78484
#
#                sumdid companyname
# 0       Powered047053        Lyft
# 1        PoweredJK1DE        Bird
# 2        PoweredTH6XP        Bird
# 3        PoweredYIYUK        Bird
# 4        Powered1NNHR        Bird
# ...               ...         ...
# 565517  Powered054136        Lyft
# 565518  Powered744710        Lyft
# 565519  Powered974720        Lyft
# 565520  Powered788506        Lyft
# 565521  Powered276841        Lyft
#
# [565522 rows x 7 columns]

# %%
loc_data_2 = '''
SELECT COUNT(startlatitude) AS trips,
       sumdid
FROM trips
WHERE startlatitude IS NOT NULL
GROUP BY sumdid
ORDER BY trips DESC
'''
with engine.connect() as connection:
    locat_data_2 = pd.read_sql(text(loc_data_2), con = connection)

# %%
locat_data_2.head(1000)
# Out:
#      trips                                       sumdid
# 0     3613                               PoweredUNKNOWN
# 1     1908  Poweredb671ffe4-2bca-5880-98ec-d36f65aa11a2
# 2      382                         PoweredR3QXO6TL2HIAB
# 3      369                         PoweredZ6HF5P5HCJCT5
# 4      352                         PoweredCL37MXJKM7RS5
# ..     ...                                          ...
# 995    134                         PoweredT5AMEDSVPIOFQ
# 996    134                         PoweredNCB6O4VINZVKG
# 997    134                         PoweredAOI4QM2LCVRBN
# 998    134                         PoweredF7KU43PTXC67B
# 999    134                         PoweredZYNSVOII2QSLD
#
# [1000 rows x 2 columns]

# %%
start_gpd_loc = gpd.GeoDataFrame(
            locat_data, geometry=gpd.points_from_xy(locat_data.startlongitude, locat_data.startlatitude), crs="EPSG:4326"
)

# %%
start_gpd_loc
# Out:
#         timestamp  startlatitude  startlongitude  endlatitude  endlongitude  \
# 0      2019-07-18       36.16200       -86.77411     36.16195     -86.77408
# 1      2019-07-18       36.16950       -86.77270     36.16670     -86.77740
# 2      2019-07-18       36.17780       -86.77750     36.18080     -86.78720
# 3      2019-07-18       36.14970       -86.80170     36.14340     -86.80630
# 4      2019-07-18       36.17780       -86.77760     36.18030     -86.78820
# ...           ...            ...             ...          ...           ...
# 565517 2019-07-18       36.15697       -86.79420     36.15241     -86.79035
# 565518 2019-07-18       36.15215       -86.79755     36.14837     -86.81381
# 565519 2019-07-18       36.15661       -86.77522     36.15502     -86.78481
# 565520 2019-07-18       36.15315       -86.79598     36.14840     -86.81383
# 565521 2019-07-18       36.15865       -86.77731     36.15504     -86.78484
#
#                sumdid companyname                    geometry
# 0       Powered047053        Lyft  POINT (-86.77411 36.16200)
# 1        PoweredJK1DE        Bird  POINT (-86.77270 36.16950)
# 2        PoweredTH6XP        Bird  POINT (-86.77750 36.17780)
# 3        PoweredYIYUK        Bird  POINT (-86.80170 36.14970)
# 4        Powered1NNHR        Bird  POINT (-86.77760 36.17780)
# ...               ...         ...                         ...
# 565517  Powered054136        Lyft  POINT (-86.79420 36.15697)
# 565518  Powered744710        Lyft  POINT (-86.79755 36.15215)
# 565519  Powered974720        Lyft  POINT (-86.77522 36.15661)
# 565520  Powered788506        Lyft  POINT (-86.79598 36.15315)
# 565521  Powered276841        Lyft  POINT (-86.77731 36.15865)
#
# [565522 rows x 8 columns]

# %%
end_gpd_loc = gpd.GeoDataFrame(
            locat_data, geometry=gpd.points_from_xy(locat_data.endlongitude, locat_data.endlatitude), crs="EPSG:4326"
)

# %%
end_gpd_loc
# Out:
#         startlatitude  startlongitude  endlatitude  endlongitude  \
# 0            36.16200       -86.77411     36.16195     -86.77408
# 1            36.16950       -86.77270     36.16670     -86.77740
# 2            36.17780       -86.77750     36.18080     -86.78720
# 3            36.14970       -86.80170     36.14340     -86.80630
# 4            36.17780       -86.77760     36.18030     -86.78820
# ...               ...             ...          ...           ...
# 565517       36.15697       -86.79420     36.15241     -86.79035
# 565518       36.15215       -86.79755     36.14837     -86.81381
# 565519       36.15661       -86.77522     36.15502     -86.78481
# 565520       36.15315       -86.79598     36.14840     -86.81383
# 565521       36.15865       -86.77731     36.15504     -86.78484
#
#                sumdid companyname                    geometry
# 0       Powered047053        Lyft  POINT (-86.77408 36.16195)
# 1        PoweredJK1DE        Bird  POINT (-86.77740 36.16670)
# 2        PoweredTH6XP        Bird  POINT (-86.78720 36.18080)
# 3        PoweredYIYUK        Bird  POINT (-86.80630 36.14340)
# 4        Powered1NNHR        Bird  POINT (-86.78820 36.18030)
# ...               ...         ...                         ...
# 565517  Powered054136        Lyft  POINT (-86.79035 36.15241)
# 565518  Powered744710        Lyft  POINT (-86.81381 36.14837)
# 565519  Powered974720        Lyft  POINT (-86.78481 36.15502)
# 565520  Powered788506        Lyft  POINT (-86.81383 36.14840)
# 565521  Powered276841        Lyft  POINT (-86.78484 36.15504)
#
# [565522 rows x 7 columns]

# %%
top_1k = '''
SELECT COUNT(triprecordnum) AS trips,
       sumdid
FROM trips
WHERE startlatitude IS NOT NULL 
GROUP BY sumdid
ORDER BY trips DESC
LIMIT(1000)
'''
with engine.connect() as connection:
    top_thousand = pd.read_sql(text(top_1k),con = connection)

# %%
top_thousand
# Out:
#      trips                                       sumdid
# 0     3613                               PoweredUNKNOWN
# 1     1908  Poweredb671ffe4-2bca-5880-98ec-d36f65aa11a2
# 2      382                         PoweredR3QXO6TL2HIAB
# 3      369                         PoweredZ6HF5P5HCJCT5
# 4      352                         PoweredCL37MXJKM7RS5
# ..     ...                                          ...
# 995    134                         Powered6O3JJSPBFODKM
# 996    134                         PoweredZION27DRWBC5F
# 997    134                                Powered014344
# 998    134                         PoweredT5AMEDSVPIOFQ
# 999    134                         PoweredF7KU43PTXC67B
#
# [1000 rows x 2 columns]

# %%
unknown_sc = '''
SELECT *
FROM trips 
WHERE sumdid = 'PoweredR3QXO6TL2HIAB'
'''
with engine.connect() as connection:
    unknown = pd.read_sql(text(unknown_sc),con = connection)

# %%
unknown
# Out:
#                pubtimestamp companyname triprecordnum                sumdid  \
# 0   2019-07-19 20:57:49.783        Lime     LIM806984  PoweredR3QXO6TL2HIAB
# 377  [(36.15658, -86.77337), (36.156439999999996, -... 2019-07-01 07:55:05.810
# 378  [(36.16898, -86.75848), (36.168839999999996, -... 2019-07-03 08:50:42.940
# 379                             [(36.16277, -86.7715)] 2019-07-03 08:52:04.940
# 380  [(36.16238, -86.77189), (36.1638, -86.76989999... 2019-07-03 08:52:07.120
# 381  [(36.16141, -86.77589), (36.16101999999999, -8... 2019-07-05 08:48:09.797
#
# [382 rows x 16 columns]

# %%
county_border = gpd.read_file('../nashville-scooters-bently/countyborder.geojson')

# %%
center = county_border.geometry.centroid[0]
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_21476\1726507251.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = county_border.geometry.centroid[0]

# %%
area_center=[center.y, center.x]
print(area_center)
# Out:
# [36.169518278335836, -86.78492656233847]

# %%
clean_latlong = start_gpd_loc.loc[start_gpd_loc.startlatitude.isnull() == False]

# %%
unk_latlong = clean_latlong.loc[clean_latlong['sumdid']=='PoweredUNKNOWN']

# %%
print(unk_latlong)
# Out:
#         timestamp  startlatitude  startlongitude  endlatitude  endlongitude  \
# 250    2019-07-18        36.1575        -86.7780      36.1575      -86.7780
# 902    2019-07-18        36.1568        -86.7693      36.1568      -86.7693
# 2354   2019-07-19        36.1584        -86.7754      36.1584      -86.7754
# 2360   2019-07-19        36.1547        -86.8014      36.1547      -86.8014
# 2641   2019-07-19        36.1674        -86.7809      36.1674      -86.7809
# ...           ...            ...             ...          ...           ...
# 563795 2019-07-17        36.1268        -86.7894      36.1268      -86.7894
# 564074 2019-07-17        36.1645        -86.7800      36.1645      -86.7800
# 565111 2019-07-18        36.1466        -86.8086      36.1466      -86.8086
# 565116 2019-07-18        36.1417        -86.8132      36.1417      -86.8132
# 565118 2019-07-18        36.1711        -86.7511      36.1711      -86.7511
#
#                 sumdid companyname                    geometry
# 250     PoweredUNKNOWN        Bird  POINT (-86.77800 36.15750)
# 902     PoweredUNKNOWN        Bird  POINT (-86.76930 36.15680)
# 2354    PoweredUNKNOWN        Bird  POINT (-86.77540 36.15840)
# 2360    PoweredUNKNOWN        Bird  POINT (-86.80140 36.15470)
# 2641    PoweredUNKNOWN        Bird  POINT (-86.78090 36.16740)
# ...                ...         ...                         ...
# 563795  PoweredUNKNOWN        Bird  POINT (-86.78940 36.12680)
# 564074  PoweredUNKNOWN        Bird  POINT (-86.78000 36.16450)
# 565111  PoweredUNKNOWN        Bird  POINT (-86.80860 36.14660)
# 565116  PoweredUNKNOWN        Bird  POINT (-86.81320 36.14170)
# 565118  PoweredUNKNOWN        Bird  POINT (-86.75110 36.17110)
#
# [3613 rows x 8 columns]

# %%
unk_latlong1 = unk_latlong[['startlatitude', 'startlongitude']]

# %%
clean_latlong2 = end_gpd_loc.loc[end_gpd_loc.endlatitude.isnull() == False]

# %%
clean_latlong2 = clean_latlong2.loc[clean_latlong2.sumdid=='Poweredb671ffe4-2bca-5880-98ec-d36f65aa11a2']

# %%
unk_latlong2 = clean_latlong2[['endlatitude', 'endlongitude']]

# %%
print(clean_latlong)
# Out:
#         startlatitude  startlongitude  endlatitude  endlongitude  \
# 0            36.16200       -86.77411     36.16195     -86.77408
# 1            36.16950       -86.77270     36.16670     -86.77740
# 2            36.17780       -86.77750     36.18080     -86.78720
# 3            36.14970       -86.80170     36.14340     -86.80630
# 4            36.17780       -86.77760     36.18030     -86.78820
# ...               ...             ...          ...           ...
# 565517       36.15697       -86.79420     36.15241     -86.79035
# 565518       36.15215       -86.79755     36.14837     -86.81381
# 565519       36.15661       -86.77522     36.15502     -86.78481
# 565520       36.15315       -86.79598     36.14840     -86.81383
# 565521       36.15865       -86.77731     36.15504     -86.78484
#
#                sumdid companyname                    geometry
# 0       Powered047053        Lyft  POINT (-86.77411 36.16200)
# 1        PoweredJK1DE        Bird  POINT (-86.77270 36.16950)
# 2        PoweredTH6XP        Bird  POINT (-86.77750 36.17780)
# 3        PoweredYIYUK        Bird  POINT (-86.80170 36.14970)
# 4        Powered1NNHR        Bird  POINT (-86.77760 36.17780)
# ...               ...         ...                         ...
# 565517  Powered054136        Lyft  POINT (-86.79420 36.15697)
# 565518  Powered744710        Lyft  POINT (-86.79755 36.15215)
# 565519  Powered974720        Lyft  POINT (-86.77522 36.15661)
# 565520  Powered788506        Lyft  POINT (-86.79598 36.15315)
# 565521  Powered276841        Lyft  POINT (-86.77731 36.15865)
#
# [565522 rows x 7 columns]

# %%
clean_latlongend = end_gpd_loc.loc[start_gpd_loc.startlatitude.isnull() == False]

# %%
latlongend = clean_latlongend[['startlatitude', 'startlongitude','companyname']]

# %%
latlongend_bird = latlongend.loc[latlongend.companyname == 'Bird']

# %%
print(latlongend_bird)
# Out:
#         startlatitude  startlongitude companyname
# 1             36.1695        -86.7727        Bird
# 2             36.1778        -86.7775        Bird
# 3             36.1497        -86.8017        Bird
# 4             36.1778        -86.7776        Bird
# 6             36.1477        -86.8057        Bird
# ...               ...             ...         ...
# 565494        36.1573        -86.7712        Bird
# 565495        36.1491        -86.7906        Bird
# 565496        36.1429        -86.8079        Bird
# 565503        36.1493        -86.8142        Bird
# 565504        36.1576        -86.7795        Bird
#
# [152745 rows x 3 columns]

# %%
latlongend_lyft = latlongend.loc[latlongend.companyname == 'Lyft']

# %%
print(latlongend_lyft)
# Out:
#         startlatitude  startlongitude companyname
# 0            36.16200       -86.77411        Lyft
# 15           36.17534       -86.78771        Lyft
# 17           36.15781       -86.78426        Lyft
# 50           36.16494       -86.78438        Lyft
# 85           36.13701       -86.80080        Lyft
# ...               ...             ...         ...
# 565517       36.15697       -86.79420        Lyft
# 565518       36.15215       -86.79755        Lyft
# 565519       36.15661       -86.77522        Lyft
# 565520       36.15315       -86.79598        Lyft
# 565521       36.15865       -86.77731        Lyft
#
# [120991 rows x 3 columns]

# %%
latlongend_bolt = latlongend.loc[latlongend.companyname == 'Bolt Mobility']

# %%
print(latlongend_bolt)
# Out:
#         startlatitude  startlongitude    companyname
# 127         36.154361      -86.798600  Bolt Mobility
# 164         36.145958      -86.811511  Bolt Mobility
# 237         36.145891      -86.810557  Bolt Mobility
# 238         36.148787      -86.813591  Bolt Mobility
# 239         36.143968      -86.807232  Bolt Mobility
# ...               ...             ...            ...
# 565303      36.164333      -86.769403  Bolt Mobility
# 565465      36.146186      -86.811664  Bolt Mobility
# 565476      36.145965      -86.811515  Bolt Mobility
# 565490      36.146215      -86.811609  Bolt Mobility
# 565499      36.148355      -86.813829  Bolt Mobility
#
# [21890 rows x 3 columns]

# %%
locations_lyft = latlongend_lyft[['startlatitude', 'startlongitude']]

# %%
lyft_list = locations_lyft.values.tolist()

# %%
fig, ax = plt.subplots(figsize=(7,7))
county_border.plot(ax=ax, facecolor='Grey', edgecolor='k',alpha=.4,linewidth=1,color='black')
unk_latlong.plot(ax=ax, cmap='coolwarm', markersize=6, alpha=.4)
plt.axis([-86.850, -86.725, 36.1, 36.2])

plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,7))
county_border.plot(ax=ax, facecolor='Grey', edgecolor='k',alpha=1,linewidth=1,cmap="cividis")
clean_latlongend.plot(ax=ax, color='red', markersize=5)
plt.show()

# %%
# Out:
# 0         POINT (-86.77408 36.16195)
# 1         POINT (-86.77740 36.16670)
# 2         POINT (-86.78720 36.18080)
# 3         POINT (-86.80630 36.14340)
# 4         POINT (-86.78820 36.18030)
#                      ...
# 565517    POINT (-86.79035 36.15241)
# 565518    POINT (-86.81381 36.14837)
# 565519    POINT (-86.78481 36.15502)
# 565520    POINT (-86.81383 36.14840)
# 565521    POINT (-86.78484 36.15504)
# Name: geometry, Length: 565522, dtype: geometry

# %%
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_37224\571602554.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   cent=fixed_coord.geometry.centroid[0]

# %%
# Out:
# POINT (-86.77408 36.16195)

# %%
# Out:
#   Cell In[57], line 7
#     ).add_to(map_end)
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
m = folium.Map([36.169518278335836, -86.78492656233847 ], zoom_start=12)
folium.plugins.HeatMap(unk_latlong1).add_to(m)
folium.TileLayer('Stamen Terrain').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d79ffe2540f9d087d38b7a723c3e3da7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d79ffe2540f9d087d38b7a723c3e3da7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d79ffe2540f9d087d38b7a723c3e3da7 = L.map(
#                 &quot;map_d79ffe2540f9d087d38b7a723c3e3da7&quot;,
#                 {
#                     center: [36.169518278335836, -86.78492656233847],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6ac8d9c535191f8953a0b570294ba33 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d79ffe2540f9d087d38b7a723c3e3da7);
#
#
#             var heat_map_db5a07c16b5a771d071b5cb651a542a0 = L.heatLayer(
